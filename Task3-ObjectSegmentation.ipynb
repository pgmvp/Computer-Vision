# %%
import numpy as np
import cv2
from skimage import io
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

def url_to_image(url):
  print("downloading %s" % (url))
  return cv2.cvtColor(io.imread(url), cv2.COLOR_BGR2RGB)

url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj3.jpg"
img = url_to_image(url)
img = cv2.resize(img, (0,0), fx=0.5, fy=0.5) 

cv2_imshow(img)
(w,h) = img.shape[:2]
mask = np.zeros( (w,h),np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (25,25,w-50,h-50)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,2,cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
cv2_imshow(mask2*255)
cv2_imshow(img)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj3.jpg
# <PIL.Image.Image image mode=RGB size=240x188 at 0x7FDFEDC98208>
# <PIL.Image.Image image mode=L size=240x188 at 0x7FDFED314A20>
# <PIL.Image.Image image mode=RGB size=240x188 at 0x7FDFED314A20>

# %%
url = "https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj4.jpg"
img = url_to_image(url)
img = cv2.resize(img, (0,0), fx=0.5, fy=0.5) 

cv2_imshow(img)
(w,h) = img.shape[:2]
mask = np.zeros( (w,h),np.uint8)
bgdModel = np.zeros((1,65),np.float64)
fgdModel = np.zeros((1,65),np.float64)
rect = (25,25,w-50,h-50)
cv2.grabCut(img,mask,rect,bgdModel,fgdModel,2,cv2.GC_INIT_WITH_RECT)
mask2 = np.where((mask==2)|(mask==0),0,1).astype('uint8')
img = img*mask2[:,:,np.newaxis]
cv2_imshow(mask2*255)
cv2_imshow(img)
# Out:
# downloading https://raw.githubusercontent.com/mdavydov/ComputerVisionCourse/master/tasks/object/obj4.jpg
# <PIL.Image.Image image mode=RGB size=240x160 at 0x7FDFEB25BBA8>
# <PIL.Image.Image image mode=L size=240x160 at 0x7FDFEB25BBA8>
# <PIL.Image.Image image mode=RGB size=240x160 at 0x7FDFEB25BBA8>
